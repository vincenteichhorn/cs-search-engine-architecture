# %%
import pstats

stats = pstats.Stats("../profile.txt")
stats.sort_stats("cumulative")   # or: "time", "calls"
stats.print_stats()
# Out:
# Fri Nov 14 14:49:19 2025    ../profile.txt
#
#          841448 function calls (826058 primitive calls) in 0.567 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     586/1    0.002    0.000    0.568    0.568 {built-in method builtins.exec}
#         1    0.000    0.000    0.568    0.568 <string>:1(<module>)
#         1    0.000    0.000    0.568    0.568 <frozen runpy>:201(run_module)
#         1    0.000    0.000    0.567    0.567 <frozen runpy>:65(_run_code)
#         1    0.000    0.000    0.567    0.567 /home/vincent/Documents/HPI/Master/SEA/cs-search-engine-architecture/test/load_doc.py:1(<module>)
#     703/4    0.003    0.000    0.562    0.141 <frozen importlib._bootstrap>:1349(_find_and_load)
#     676/4    0.002    0.000    0.562    0.141 <frozen importlib._bootstrap>:1304(_find_and_load_unlocked)
#     640/5    0.002    0.000    0.562    0.112 <frozen importlib._bootstrap>:911(_load_unlocked)
# ...
